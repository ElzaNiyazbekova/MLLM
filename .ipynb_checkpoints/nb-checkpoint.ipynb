# %% [markdown]
# # 1. Headings
# ## Heading 2

# %% [markdown]
# <div align="center">Aligning by center</div>

# %% [markdown]
# <h1 align="center" style = "color:blue">Centered heading</h1>

# %% [markdown]
# **bold text**
# **Bold Text**
# *Italic text*

# %% [markdown]
# - Milk

# %% [markdown]
# - Water - white
#
#     - Item 3

# %% [markdown]
# 1. Milk

# %% [markdown]
# [Jupyter](http://localhost:8888/lab/tree/Untitled.ipynb?)

# %% [markdown]
# ![text](https://jupyter.org/assets/homepage/main-logo.svg)

# %% [markdown]
# <img src="https://jupyter.org/assets/homepage/main-logo.svg" width="200">

# %% [markdown]
# ```python
# def hello():
#  print("Hello, Jupyter!")

# %% [markdown]
# | Name | Age | Country |
# | ---- | --- | ------- |
# | Alice | 23 | Usa |
# | Shjk | 19 | Kz |

# %% [markdown]
# ---

# %% [markdown]
# > Blockquote 1
#
# > Blockquote 2

# %% [markdown]
# 1. Python
#     - Data
#     - Ml

# %% [markdown]
# $$ \int_2^1 x^2 dx = \frac{3}{4}$$

# %% [markdown]
# $$ E = m c^2 $$

# %% [markdown]
# ~~Text is crossed~~

# %% [markdown]
# <p style = "color:purple" width=200>Purple text</p>

# %% [markdown]
# <img src="Eager_learning.png" width="200">

# %% [markdown]
# <table>
# <tr>
# <td><img src="https://jupyter.org/assets/homepage/main-logo.svg" width="150"></td>
# <td>This image represents how robot is learning.</td>
# </tr>
# </table>

# %% [markdown]
# - [x] Learn markdown
# - [x] Practice markdown

# %% [markdown]
# # 🦄💕🧚‍♀️

# %% [markdown]
# # 🌈🎀💘

# %% [markdown]
# <img src="data:image/jpeg;base64,...">

# %% [markdown]
# *<h1 >Goodbye </h1>*
