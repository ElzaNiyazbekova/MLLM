# %% [markdown]
# # Task 1: Create Normal Headings
# Write Markdown to create:
#
# A level 1 heading: "My Title"
#
# A level 2 heading: "My Subtitle"
#
# A level 3 heading: "My Section"

# %% [markdown]
# # My Title

# %% [markdown]
# ## My Subtitle

# %% [markdown]
# ### My Section

# %% [markdown]
# # Task 2: Center a Heading
# Create a centered heading: "Welcome to My Notebook".

# %% [markdown]
# <h1 align="center">Welcome to My Notebook</h1>

# %% [markdown]
# # Task 3: Insert an Image
# Insert an image using the Markdown syntax:
#
# Hint: Use any sample image from your computer (e.g., cat.png ) or a link to an online image.

# %% [markdown]
# ![text](https://www.bu.edu/files/2024/08/Hey-BU-Blog-Headers.jpg)

# %% [markdown]
# # Task 4: Resize an Image
# Resize an image to 200px width using HTML inside Markdown.

# %% [markdown]
# <img src="https://www.bu.edu/files/2024/08/Hey-BU-Blog-Headers.jpg"  width="200">

# %% [markdown]
# # Task 5: Image + Text Side by Side
# Insert an image on the left and some text on the right.

# %% [markdown]
# <table>
# <tr>
# <td><img src="https://cdn-images.dzcdn.net/images/cover/24b5c291c0bb35c11451cb8d4136c712/500x500-000000-80-0-0.jpg" width="200"></td>
# <td>Image + text.</td>
# </tr>
# </table>

# %% [markdown]
# # Task 6: Display 3 Images Side by Side
# Insert three images next to each other in the same row.

# %% [markdown]
# <div style="display:flex; justify-content:center; gap:10px;">
#   <img src="https://cdn-images.dzcdn.net/images/cover/24b5c291c0bb35c11451cb8d4136c712/500x500-000000-80-0-0.jpg" width="150">
#   <img src="https://pbs.twimg.com/media/EbwsDU9WoAEXp2T?format=jpg&name=240x240" width="150">
#   <img src="https://www.bu.edu/files/2024/08/Hey-BU-Blog-Headers.jpg" width="150">
# </div>

# %% [markdown]
# # Challenging Task: Centered Title with an Image
# Create a centered heading: "My Favorite Animal" and display an image right below it,
# centered.

# %% [markdown]
# <h1 align="center">My Favorite Animal</h1>
# <table>
# <tr>
# <td><img src="https://cdn-images.dzcdn.net/images/cover/24b5c291c0bb35c11451cb8d4136c712/500x500-000000-80-0-0.jpg" width="200"></td>
# </tr>
# </table>
